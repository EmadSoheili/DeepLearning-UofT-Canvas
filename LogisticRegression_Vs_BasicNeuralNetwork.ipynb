# %% [markdown]
# <a href="https://colab.research.google.com/github/EmadSoheili/DeepLearning-UofT-Canvas/blob/main/LogisticRegression_Vs_BasicNeuralNetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import our dependencies

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# %%
# Import our input dataset

diabetes_df = pd.read_csv('Inputs/diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Split data into inputs and output

y = diabetes_df.Outcome
X = diabetes_df.drop(columns="Outcome")

# %%
# Split data into train and test

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Scale data

scaler = StandardScaler()
X_scaler = scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Logistic Rregression

# Model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)
log_classifier.fit(X_train,y_train)

# Evaluation

y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %%
# Basic Neural Network

# Model

nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=8))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluation

model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/50
# 18/18 [==============================] - 1s 2ms/step - loss: 0.6553 - accuracy: 0.6337
# Epoch 2/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6309 - accuracy: 0.6493
# Epoch 3/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6101 - accuracy: 0.6632
# Epoch 4/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5904 - accuracy: 0.6719
# Epoch 5/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5736 - accuracy: 0.6875
# Epoch 6/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5573 - accuracy: 0.6979
# Epoch 7/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5431 - accuracy: 0.7083
# Epoch 8/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5306 - accuracy: 0.7222
# Epoch 9/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5195 - accuracy: 0.7292
# Epoch 10/50
# ...

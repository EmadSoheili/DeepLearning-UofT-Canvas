# %% [markdown]
# <a href="https://colab.research.google.com/github/EmadSoheili/DeepLearning-UofT-NeuralNetworksCanvas/blob/main/NeuralNetwork_MoonShapedData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import our dependencies

import pandas as pd
import matplotlib as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons

# %matplotlib inline

# %%
# Create moon-shaped data

X_moons, y_moons = make_moons(n_samples=1000, noise=0.08, random_state=78)

# Transforming y_moons to a vertical vector

y_moons = y_moons.reshape(-1, 1)

# %%
# Plot data

df_moons = pd.DataFrame(X_moons, columns=['Feature 1', 'Feature 2'])
df_moons['Target'] = y_moons
df_moons.plot.scatter(x='Feature 1', y='Feature 2', c='Target', colormap='winter')

# %%
# Create training and testing sets

X_moon_train, X_moon_test, y_moon_train, y_moon_test = train_test_split(
    X_moons, y_moons, random_state=78
)

# %%
# Create the scaler instance

X_moon_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler

X_moon_scaler.fit(X_moon_train)

# Scale the data

X_moon_train_scaled = X_moon_scaler.transform(X_moon_train)
X_moon_test_scaled = X_moon_scaler.transform(X_moon_test)

# %%
# Create the Keras Sequential model

nn_model = tf.keras.models.Sequential()

# Add first Dense layer, including the input layer

nn_model.add(tf.keras.layers.Dense(units=1, activation='relu', input_dim=2))

# Compile the Sequential model together and customize metircs

nn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Compile the Sequential model together and customize metircs

nn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model with nonlinear data

model_moon = nn_model.fit(X_moon_train_scaled, y_moon_train, epochs=100, shuffle=True)
# Out:
# Epoch 1/300
# 24/24 [==============================] - 1s 2ms/step - loss: 4.1078 - accuracy: 0.5653
# Epoch 2/300
# 24/24 [==============================] - 0s 1ms/step - loss: 4.0260 - accuracy: 0.5760
# Epoch 3/300
# 24/24 [==============================] - 0s 2ms/step - loss: 3.9600 - accuracy: 0.5813
# Epoch 4/300
# 24/24 [==============================] - 0s 2ms/step - loss: 3.9141 - accuracy: 0.5893
# Epoch 5/300
# 24/24 [==============================] - 0s 2ms/step - loss: 3.8153 - accuracy: 0.5920
# Epoch 6/300
# 24/24 [==============================] - 0s 3ms/step - loss: 3.7864 - accuracy: 0.5920
# Epoch 7/300
# 24/24 [==============================] - 0s 3ms/step - loss: 3.7747 - accuracy: 0.5973
# Epoch 8/300
# 24/24 [==============================] - 0s 3ms/step - loss: 3.7497 - accuracy: 0.6027
# Epoch 9/300
# 24/24 [==============================] - 0s 3ms/step - loss: 3.7248 - accuracy: 0.6080
# Epoch 10/300
# ...

# %%
# Plot Loss
history_df = pd.DataFrame(model_moon.history, index=range(1,len(model_moon.history["loss"])+1))
history_df.plot(y="loss")

# %%
# Plot accuracy
history_df.plot(y="accuracy")

# %%
# New model

new_model = tf.keras.models.Sequential()

# Add Input and hidden layer

number_inputs = 2
number_hidden_nodes = 6
new_model.add(tf.keras.layers.Dense(units = number_hidden_nodes, activation = 'relu', input_dim = number_inputs))

# Add output layer

new_model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Compile

new_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Fit model

new_fit_model = new_model.fit(X_moon_train_scaled, y_moon_train, epochs=100, shuffle=True)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 2ms/step - loss: 1.1919 - accuracy: 0.1587
# Epoch 2/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.1127 - accuracy: 0.1680
# Epoch 3/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0412 - accuracy: 0.1800
# Epoch 4/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9766 - accuracy: 0.2027
# Epoch 5/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9156 - accuracy: 0.2213
# Epoch 6/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8606 - accuracy: 0.2560
# Epoch 7/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8090 - accuracy: 0.2947
# Epoch 8/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7610 - accuracy: 0.3480
# Epoch 9/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7167 - accuracy: 0.4067
# Epoch 10/100
# ...
